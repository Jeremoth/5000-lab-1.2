# %% [markdown]
# ---
# title: "Lab Slides"
# format:
#   revealjs:
#     slide-number: true
#     code-fold: true
# bibliography: ../reference.bib
# ---

# %% [markdown]
# ## Introduction
#
# Welcome to my lab presentation.
# This slide demonstrates Reveal.js in Quarto.
#
# ## Images and Citation
#
# Here is an image:
#
# ![Plot Example](../images/IMG_0013.jpeg)
#
# Another image:
#
# ![Another Plot](../images/IMG_1486.jpeg)
#
# Cited work: [@gelman1995bayesian]
#
# ## Summary
#
# - Quarto integrates text and code
# - Reveal.js creates presentations
# - Citations work with BibTeX

# %%
#| echo: true
# This code cell will be foldable in reveal.js

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 200)
y = np.cos(x)

plt.figure(figsize=(6,4))
plt.plot(x, y, label="cos(x)")
plt.title("Cosine Function")
plt.legend()
plt.show()
